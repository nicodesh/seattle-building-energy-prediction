# %% [markdown]
# # Seattle Building Energy Forecasting
#
# URL: https://www.kaggle.com/city-of-seattle/sea-building-energy-benchmarking
#
# ## Notebook n°1 - Data Cleaning - Part 1
#
# Objective : Create a unique dataframe from the 2015 and 2016 data

# %% [markdown]
# #### Import librairies

# %%
from ast import literal_eval
import pickle
import pandas as pd

# %% [markdown]
# #### Display Settings

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# #### Import data

# %%
df2015 = pd.read_csv("data/2015-building-energy-benchmarking.csv")
df2016 = pd.read_csv("data/2016-building-energy-benchmarking.csv")

# %% [markdown]
# #### Shape

# %%
print(df2015.shape)
print(df2016.shape)
# Out:
# (3340, 47)
# (3376, 46)

# %% [markdown]
# #### Preview

# %%
# 2015
df2015.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'human_address': '...                    7
# 1  {'latitude': '47.61310583', 'human_address': '...                    7
# ...

# %%
# 2016
df2016.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2016  NonResidential               Hotel
# 1              2      2016  NonResidential               Hotel
# 2              3      2016  NonResidential               Hotel
# 3              5      2016  NonResidential               Hotel
# 4              8      2016  NonResidential               Hotel
#
#                   PropertyName          Address     City State  ZipCode  \
# 0         Mayflower park hotel    405 Olive way  Seattle    WA  98101.0
# 1              Paramount Hotel  724 Pine street  Seattle    WA  98101.0
# 2      5673-The Westin Seattle  1900 5th Avenue  Seattle    WA  98101.0
# 3                    HOTEL MAX   620 STEWART ST  Seattle    WA  98101.0
# 4  WARWICK SEATTLE HOTEL (ID8)    401 LENORA ST  Seattle    WA  98121.0
#
#   TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  Latitude  \
# ...

# %% [markdown]
# #### Functions

# %%
def f1_not_f2(f1, f2):
    col_warning = []
    for col in f1.columns:
        if col not in f2.columns:
            col_warning.append(col)
    
    return col_warning

# %% [markdown]
# #### NaN by feature

# %%
# 2015
pd.DataFrame(round(df2015.isna().sum().sort_values(ascending=False) / len(df2015),3))
# Out:
#                                                         0
# Comment                                             0.996
# Outlier                                             0.975
# YearsENERGYSTARCertified                            0.967
# City Council Districts                              0.936
# 2010 Census Tracts                                  0.933
# ThirdLargestPropertyUseTypeGFA                      0.832
# ThirdLargestPropertyUseType                         0.832
# SecondLargestPropertyUseTypeGFA                     0.533
# SecondLargestPropertyUseType                        0.533
# ENERGYSTARScore                                     0.234
# LargestPropertyUseTypeGFA                           0.041
# LargestPropertyUseType                              0.041
# ListOfAllPropertyUseTypes                           0.038
# SiteEnergyUse(kBtu)                                 0.003
# SiteEUI(kBtu/sf)                                    0.003
# ...

# %%
# 2016
pd.DataFrame(round(df2016.isna().sum().sort_values(ascending=False) / len(df2015),3))
# Out:
#                                      0
# Comments                         1.011
# Outlier                          1.001
# YearsENERGYSTARCertified         0.975
# ThirdLargestPropertyUseType      0.832
# ThirdLargestPropertyUseTypeGFA   0.832
# SecondLargestPropertyUseType     0.508
# SecondLargestPropertyUseTypeGFA  0.508
# ENERGYSTARScore                  0.252
# LargestPropertyUseTypeGFA        0.006
# LargestPropertyUseType           0.006
# ZipCode                          0.005
# SourceEUI(kBtu/sf)               0.003
# ListOfAllPropertyUseTypes        0.003
# TotalGHGEmissions                0.003
# GHGEmissionsIntensity            0.003
# NaturalGas(therms)               0.003
# SourceEUIWN(kBtu/sf)             0.003
# NaturalGas(kBtu)                 0.003
# SteamUse(kBtu)                   0.003
# Electricity(kWh)                 0.003
# Electricity(kBtu)                0.003
# NumberofBuildings                0.002
# SiteEUI(kBtu/sf)                 0.002
# ...

# %% [markdown]
# #### Total rows 2015 + 2016

# %%
pd.concat([df2015, df2016], sort=False).shape
# Out:
# (6716, 56)

# %% [markdown]
# #### Total unique rows 2015 + 2016

# %%
pd.concat([df2015, df2016], sort=False).drop_duplicates().shape
# Out:
# (6716, 56)

# %% [markdown]
# #### Columns existing in 2015 but not in 2016

# %%
f1_not_f2(df2015, df2016)
# Out:
# ['Location',
#  'OtherFuelUse(kBtu)',
#  'GHGEmissions(MetricTonsCO2e)',
#  'GHGEmissionsIntensity(kgCO2e/ft2)',
#  'Comment',
#  '2010 Census Tracts',
#  'Seattle Police Department Micro Community Policing Plan Areas',
#  'City Council Districts',
#  'SPD Beats',
#  'Zip Codes']

# %% [markdown]
# #### Columns existing in 2016 but not in 2015

# %%
f1_not_f2(df2016, df2015)
# Out:
# ['Address',
#  'City',
#  'State',
#  'ZipCode',
#  'Latitude',
#  'Longitude',
#  'Comments',
#  'TotalGHGEmissions',
#  'GHGEmissionsIntensity']

# %% [markdown]
# #### Flatten the "Location" feature in the 2015 dataframe

# %%
# Flatten the "Location" feature
df2015["Location"] = df2015["Location"].apply(literal_eval)

# Extract features
df2015["Latitude"] = df2015["Location"].apply(lambda x: x["latitude"])
df2015["Longitude"] = df2015["Location"].apply(lambda x: x["longitude"])
df2015["human_address"] = df2015["Location"].apply(lambda x: x["human_address"])

# Flatten the "Human Address" feature
df2015["human_address"] = df2015["human_address"].apply(literal_eval)

# Extract features
df2015["Address"] = df2015["human_address"].apply(lambda x: x["address"])
df2015["City"] = df2015["human_address"].apply(lambda x: x["city"])
df2015["State"] = df2015["human_address"].apply(lambda x: x["state"])
df2015["ZipCode"] = df2015["human_address"].apply(lambda x: x["zip"])

# Remove useless columns
df2015.drop(["Location", "human_address"], axis=1, inplace=True)

# %% [markdown]
# #### Columns existing in 2015 but not in 2016

# %%
f1_not_f2(df2015, df2016)
# Out:
# ['OtherFuelUse(kBtu)',
#  'GHGEmissions(MetricTonsCO2e)',
#  'GHGEmissionsIntensity(kgCO2e/ft2)',
#  'Comment',
#  '2010 Census Tracts',
#  'Seattle Police Department Micro Community Policing Plan Areas',
#  'City Council Districts',
#  'SPD Beats',
#  'Zip Codes']

# %% [markdown]
# #### Columns existing in 2016 but not in 2015

# %%
f1_not_f2(df2016, df2015)
# Out:
# ['Comments', 'TotalGHGEmissions', 'GHGEmissionsIntensity']

# %% [markdown]
# #### Rename some columns to match

# %%
df2016.rename(columns={"Comments": "Comment"}, inplace=True)

df2015.rename(columns={
    "GHGEmissions(MetricTonsCO2e)": "TotalGHGEmissions",
    "GHGEmissionsIntensity(kgCO2e/ft2)": "GHGEmissionsIntensity"}, inplace=True)

# %% [markdown]
# #### Columns existing in 2015 but not in 2016

# %%
f1_not_f2(df2015, df2016)
# Out:
# ['OtherFuelUse(kBtu)',
#  '2010 Census Tracts',
#  'Seattle Police Department Micro Community Policing Plan Areas',
#  'City Council Districts',
#  'SPD Beats',
#  'Zip Codes']

# %% [markdown]
# #### Let's have a look at this features

# %%
print(df2015["OtherFuelUse(kBtu)"].isna().sum())
df2015["OtherFuelUse(kBtu)"].describe()
# Out:
# 10
# count    3.330000e+03
# mean     7.142301e+03
# std      1.962790e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      8.269669e+06
# Name: OtherFuelUse(kBtu), dtype: float64

# %%
print(df2015["2010 Census Tracts"].isna().sum())
df2015["2010 Census Tracts"].describe()
# Out:
# 3116
# count    224.000000
# mean     123.062500
# std        5.812128
# min      116.000000
# 25%      117.000000
# 50%      123.000000
# 75%      125.500000
# max      135.000000
# Name: 2010 Census Tracts, dtype: float64

# %%
print(df2015["Seattle Police Department Micro Community Policing Plan Areas"].isna().sum())
df2015["Seattle Police Department Micro Community Policing Plan Areas"].describe()
# Out:
# 2
# count    3338.000000
# mean       32.380168
# std        19.907567
# min         1.000000
# 25%        14.000000
# 50%        33.000000
# 75%        50.000000
# max        61.000000
# Name: Seattle Police Department Micro Community Policing Plan Areas, dtype: float64

# %%
print(df2015["City Council Districts"].isna().sum())
df2015["City Council Districts"].describe()
# Out:
# 3127
# count    213.000000
# mean       1.347418
# std        0.477272
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000
# Name: City Council Districts, dtype: float64

# %%
print(df2015["SPD Beats"].isna().sum())
df2015["SPD Beats"].describe()
# Out:
# 2
# count    3338.000000
# mean       24.825644
# std        15.006287
# min         1.000000
# 25%        10.000000
# 50%        26.000000
# 75%        38.000000
# max        51.000000
# Name: SPD Beats, dtype: float64

# %%
print(df2015["Zip Codes"].isna().sum())
df2015["Zip Codes"].describe()
# Out:
# 0
# count     3340.000000
# mean     18786.680240
# std        588.604192
# min      17916.000000
# 25%      18379.000000
# 50%      18390.000000
# 75%      19576.000000
# max      19584.000000
# Name: Zip Codes, dtype: float64

# %% [markdown]
# #### Now we remove them

# %%
df2015.drop(f1_not_f2(df2015, df2016), axis=1, inplace=True)

# %% [markdown]
# #### And we concatenate the two dataframes

# %%
df_final = pd.concat([df2015, df2016], sort=False)

# %%
df_final.shape
# Out:
# (6716, 46)

# %% [markdown]
# #### Save the final dataframe

# %%
with open("data/part1.pkl", "wb") as f:
    my_pickle = pickle.Pickler(f)
    my_pickle.dump(df_final)
